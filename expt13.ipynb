# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("housing.csv")

data_encoded = pd.get_dummies(data)

print("Covariance:\n", data_encoded.cov())

# Covariance


# Correlation
data_encoded = pd.get_dummies(data)
corr = data_encoded.corr()
print("Correlation Matrix:\n", corr)

# Heatmap
sns.heatmap(corr, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Covariance:
#                                 longitude      latitude  housing_median_age  \
# longitude                       4.014139     -3.957054           -2.728244
# latitude                       -3.957054      4.562293            0.300346
# housing_median_age             -2.728244      0.300346          158.396260
# total_rooms                   194.803750   -168.217847        -9919.120060
# total_bedrooms                 58.768508    -60.299623        -1700.312817
# population                    226.377839   -263.137814        -4222.270582
# households                     42.368072    -58.010245        -1457.581290
# median_income                  -0.057765     -0.323860           -2.846140
# median_house_value         -10627.425205 -35532.559074       153398.801329
# ocean_proximity_<1H OCEAN       0.319571     -0.474212            0.283185
# ocean_proximity_INLAND         -0.051828      0.349139           -1.386321
# ocean_proximity_ISLAND          0.000295     -0.000551            0.003334
# ocean_proximity_NEAR BAY       -0.298579      0.240683            1.008652
# ocean_proximity_NEAR OCEAN      0.030541     -0.115060            0.091150
#
#                              total_rooms  total_bedrooms    population  \
# longitude                   1.948037e+02    5.876851e+01  2.263778e+02
# latitude                   -1.682178e+02   -6.029962e+01 -2.631378e+02
# housing_median_age         -9.919120e+03   -1.700313e+03 -4.222271e+03
# total_rooms                 4.759445e+06    8.567306e+05  2.117613e+06
# total_bedrooms              8.567306e+05    1.775654e+05  4.191391e+05
# population                  2.117613e+06    4.191391e+05  1.282470e+06
# households                  7.661046e+05    1.578295e+05  3.928036e+05
# median_income               8.208524e+02   -6.180851e+00  1.040098e+01
# median_house_value          3.377289e+07    2.416878e+06 -3.221249e+06
# ocean_proximity_<1H OCEAN  -3.284292e+00    3.832832e+00  4.196998e+01
# ocean_proximity_INLAND      2.602108e+01   -1.268212e+00 -1.092854e+01
# ocean_proximity_ISLAND     -2.570772e-01   -2.874671e-02 -1.835062e-01
# ocean_proximity_NEAR BAY   -1.577487e+01   -2.631713e+00 -2.165390e+01
# ocean_proximity_NEAR OCEAN -6.704844e+00    9.583927e-02 -9.204040e+00
#
#                               households  median_income  median_house_value  \
# longitude                   4.236807e+01      -0.057765       -1.062743e+04
# latitude                   -5.801024e+01      -0.323860       -3.553256e+04
# housing_median_age         -1.457581e+03      -2.846140        1.533988e+05
# total_rooms                 7.661046e+05     820.852410        3.377289e+07
# total_bedrooms              1.578295e+05      -6.180851        2.416878e+06
# population                  3.928036e+05      10.400979       -3.221249e+06
# households                  1.461760e+05       9.466667        2.904924e+06
# median_income               9.466667e+00       3.609323        1.508475e+05
# median_house_value          2.904924e+06  150847.482793        1.331615e+10
# ocean_proximity_<1H OCEAN   8.058699e+00       0.159361        1.470882e+04
# ocean_proximity_INLAND     -7.012231e+00      -0.210021       -2.604353e+04
# ocean_proximity_ISLAND     -5.400932e-02      -0.000273        4.205247e+01
# ocean_proximity_NEAR BAY   -1.212019e+00       0.033532        5.809214e+03
# ocean_proximity_NEAR OCEAN  2.195615e-01       0.017401        5.483442e+03
#
#                             ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# longitude                                    0.319571               -0.051828
# latitude                                    -0.474212                0.349139
# housing_median_age                           0.283185               -1.386321
# total_rooms                                 -3.284292               26.021079
# total_bedrooms                               3.832832               -1.268212
# population                                  41.969982              -10.928541
# households                                   8.058699               -7.012231
# median_income                                0.159361               -0.210021
# median_house_value                       14708.817710           -26043.526022
# ocean_proximity_<1H OCEAN                    0.246721               -0.140496
# ocean_proximity_INLAND                      -0.140496                0.216665
# ocean_proximity_ISLAND                      -0.000107               -0.000077
# ocean_proximity_NEAR BAY                    -0.049113               -0.035216
# ocean_proximity_NEAR OCEAN                  -0.057005               -0.040876
#
#                             ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# longitude                                 0.000295                 -0.298579
# latitude                                 -0.000551                  0.240683
# housing_median_age                        0.003334                  1.008652
# total_rooms                              -0.257077                -15.774866
# total_bedrooms                           -0.028747                 -2.631713
# population                               -0.183506                -21.653895
# households                               -0.054009                 -1.212019
# median_income                            -0.000273                  0.033532
# median_house_value                       42.052469               5809.214268
# ocean_proximity_<1H OCEAN                -0.000107                 -0.049113
# ocean_proximity_INLAND                   -0.000077                 -0.035216
# ocean_proximity_ISLAND                    0.000242                 -0.000027
# ocean_proximity_NEAR BAY                 -0.000027                  0.098645
# ocean_proximity_NEAR OCEAN               -0.000031                 -0.014289
#
#                             ocean_proximity_NEAR OCEAN
# longitude                                     0.030541
# latitude                                     -0.115060
# housing_median_age                            0.091150
# total_rooms                                  -6.704844
# total_bedrooms                                0.095839
# population                                   -9.204040
# households                                    0.219562
# median_income                                 0.017401
# median_house_value                         5483.441574
# ocean_proximity_<1H OCEAN                    -0.057005
# ocean_proximity_INLAND                       -0.040876
# ocean_proximity_ISLAND                       -0.000031
# ocean_proximity_NEAR BAY                     -0.014289
# ocean_proximity_NEAR OCEAN                    0.112200
# Correlation Matrix:
#                              longitude  latitude  housing_median_age  \
# longitude                    1.000000 -0.924664           -0.108197
# latitude                    -0.924664  1.000000            0.011173
# housing_median_age          -0.108197  0.011173            1.000000
# total_rooms                  0.044568 -0.036100           -0.361262
# total_bedrooms               0.069608 -0.066983           -0.320451
# population                   0.099773 -0.108785           -0.296244
# households                   0.055310 -0.071035           -0.302916
# median_income               -0.015176 -0.079809           -0.119034
# median_house_value          -0.045967 -0.144160            0.105623
# ocean_proximity_<1H OCEAN    0.321121 -0.446969            0.045300
# ocean_proximity_INLAND      -0.055575  0.351166           -0.236645
# ocean_proximity_ISLAND       0.009446 -0.016572            0.017020
# ocean_proximity_NEAR BAY    -0.474489  0.358771            0.255172
# ocean_proximity_NEAR OCEAN   0.045509 -0.160818            0.021622
#
#                             total_rooms  total_bedrooms  population  \
# longitude                      0.044568        0.069608    0.099773
# latitude                      -0.036100       -0.066983   -0.108785
# housing_median_age            -0.361262       -0.320451   -0.296244
# total_rooms                    1.000000        0.930380    0.857126
# total_bedrooms                 0.930380        1.000000    0.877747
# population                     0.857126        0.877747    1.000000
# households                     0.918484        0.979728    0.907222
# median_income                  0.198050       -0.007723    0.004834
# median_house_value             0.134153        0.049686   -0.024650
# ocean_proximity_<1H OCEAN     -0.003031        0.018314    0.074613
# ocean_proximity_INLAND         0.025624       -0.006463   -0.020732
# ocean_proximity_ISLAND        -0.007572       -0.004361   -0.010412
# ocean_proximity_NEAR BAY      -0.023022       -0.019873   -0.060880
# ocean_proximity_NEAR OCEAN    -0.009175        0.000679   -0.024264
#
#                             households  median_income  median_house_value  \
# longitude                     0.055310      -0.015176           -0.045967
# latitude                     -0.071035      -0.079809           -0.144160
# housing_median_age           -0.302916      -0.119034            0.105623
# total_rooms                   0.918484       0.198050            0.134153
# total_bedrooms                0.979728      -0.007723            0.049686
# population                    0.907222       0.004834           -0.024650
# households                    1.000000       0.013033            0.065843
# median_income                 0.013033       1.000000            0.688075
# median_house_value            0.065843       0.688075            1.000000
# ocean_proximity_<1H OCEAN     0.042435       0.168876            0.256617
# ocean_proximity_INLAND       -0.039402      -0.237496           -0.484859
# ocean_proximity_ISLAND       -0.009077      -0.009228            0.023416
# ocean_proximity_NEAR BAY     -0.010093       0.056197            0.160284
# ocean_proximity_NEAR OCEAN    0.001714       0.027344            0.141862
#
#                             ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# longitude                                    0.321121               -0.055575
# latitude                                    -0.446969                0.351166
# housing_median_age                           0.045300               -0.236645
# total_rooms                                 -0.003031                0.025624
# total_bedrooms                               0.018314               -0.006463
# population                                   0.074613               -0.020732
# households                                   0.042435               -0.039402
# median_income                                0.168876               -0.237496
# median_house_value                           0.256617               -0.484859
# ocean_proximity_<1H OCEAN                    1.000000               -0.607669
# ocean_proximity_INLAND                      -0.607669                1.000000
# ocean_proximity_ISLAND                      -0.013872               -0.010614
# ocean_proximity_NEAR BAY                    -0.314813               -0.240887
# ocean_proximity_NEAR OCEAN                  -0.342620               -0.262163
#
#                             ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# longitude                                 0.009446                 -0.474489
# latitude                                 -0.016572                  0.358771
# housing_median_age                        0.017020                  0.255172
# total_rooms                              -0.007572                 -0.023022
# total_bedrooms                           -0.004361                 -0.019873
# population                               -0.010412                 -0.060880
# households                               -0.009077                 -0.010093
# median_income                            -0.009228                  0.056197
# median_house_value                        0.023416                  0.160284
# ocean_proximity_<1H OCEAN                -0.013872                 -0.314813
# ocean_proximity_INLAND                   -0.010614                 -0.240887
# ocean_proximity_ISLAND                    1.000000                 -0.005499
# ocean_proximity_NEAR BAY                 -0.005499                  1.000000
# ocean_proximity_NEAR OCEAN               -0.005985                 -0.135818
#
#                             ocean_proximity_NEAR OCEAN
# longitude                                     0.045509
# latitude                                     -0.160818
# housing_median_age                            0.021622
# total_rooms                                  -0.009175
# total_bedrooms                                0.000679
# population                                   -0.024264
# households                                    0.001714
# median_income                                 0.027344
# median_house_value                            0.141862
# ocean_proximity_<1H OCEAN                    -0.342620
# ocean_proximity_INLAND                       -0.262163
# ocean_proximity_ISLAND                       -0.005985
# ocean_proximity_NEAR BAY                     -0.135818
# ocean_proximity_NEAR OCEAN                    1.000000
