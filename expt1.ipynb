# %%
import numpy as np 
import matplotlib.pyplot as plt 
 
N = 10000 
uniform = np.random.uniform(0, 1, N) 
normal = np.random.normal(0, 1, N) 
exponential = np.random.exponential(1, N) 
 
for data, title in zip([uniform, normal, exponential], 
                       ['Uniform', 'Normal', 'Exponential']): 
    plt.hist(data, bins=50) 
    plt.title(title) 
    plt.show() 
    print(f"{title} Mean:", np.mean(data)) 
    print(f"{title} Std:", np.std(data))
# Out:
# Uniform Mean: 0.5056053893459308
# Uniform Std: 0.2899229569293754
# Normal Mean: -0.007732876837186757
# Normal Std: 1.003611048860575
# Exponential Mean: 1.007705357670023
# Exponential Std: 0.9959310670294653
