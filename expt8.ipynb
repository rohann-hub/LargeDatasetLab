# %%
import numpy as np 
data = np.random.normal(100, 15, 100) 
boot_means = [] 
for _ in range(1000): 
    sample = np.random.choice(data, size=len(data), replace=True) 
    boot_means.append(np.mean(sample)) 
print('Bootstrap Mean:', np.mean(boot_means))
# Out:
# Bootstrap Mean: 99.74485220648879
